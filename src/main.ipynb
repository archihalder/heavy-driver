# %% [markdown]
# ## Importing Libraries

# %%
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential

# %matplotlib inline
# Out:
# 2022-05-09 12:03:42.234187: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-09 12:03:42.234273: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
data_dir = '../data/'
train_path = '../data/Train'
IMG_HEIGHT = 30
IMG_WIDTH = 30

# %%
# Number of Classes
NUM_CATEGORIES = len(os.listdir(train_path))
NUM_CATEGORIES
# Out:
# 43

# %%
# Visualizing all the different Signs
img_dir = pathlib.Path(train_path)
plt.figure(figsize=(14,14))
index = 0
for i in range(NUM_CATEGORIES):
    plt.subplot(7, 7, i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    sign = list(img_dir.glob(f'{i}/*'))[0]
    img = load_img(sign, target_size=(IMG_WIDTH, IMG_HEIGHT))
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Loading the data

# %%
def load_data(data_dir):
    '''
    Loading data from Train folder.
    
    Returns a tuple `(images, labels)` , where `images` is a list of all the images in the train directory,
    where each image is formatted as a numpy ndarray with dimensions IMG_WIDTH x IMG_HEIGHT x 3. 
    `labels` is a list of integer labels, representing the categories for each of the
    corresponding `images`.
    '''
    images = list()
    labels = list()
    for category in range(NUM_CATEGORIES):
        categories = os.path.join(data_dir, str(category))
        for img in os.listdir(categories):
            img = load_img(os.path.join(categories, img), target_size=(30, 30))
            image = img_to_array(img)
            images.append(image)
            labels.append(category)
    
    return images, labels

# %%
images, labels = load_data(train_path)

# One hot encoding the labels
labels = to_categorical(labels)

# Splitting the dataset into training and test set
x_train, x_test, y_train, y_test = train_test_split(np.array(images), labels, test_size=0.4)

# %% [markdown]
# ## Building the model

# %%
model = Sequential()

# First Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=(IMG_HEIGHT,IMG_WIDTH,3)))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

# Second Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))

# Third Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))

model.summary()
# Out:
# 2022-05-09 12:04:48.435990: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-05-09 12:04:48.436017: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-05-09 12:04:48.436044: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (fedora): /proc/driver/nvidia/version does not exist
# 2022-05-09 12:04:48.436210: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Flattening the layer and adding Dense Layer
model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(NUM_CATEGORIES, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 43)                2795
#
# =================================================================
# Total params: 124,715
# Trainable params: 124,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Fitting the model
EPOCHS = 30
history = model.fit(x_train, y_train,
                    validation_data = (x_test, y_test), 
                    epochs=EPOCHS, steps_per_epoch=60)
# Out:
# Epoch 1/30
# 60/60 [==============================] - 10s 152ms/step - loss: 6.0872 - accuracy: 0.0464 - val_loss: 3.7169 - val_accuracy: 0.0720
# Epoch 2/30
# 60/60 [==============================] - 9s 146ms/step - loss: 3.6776 - accuracy: 0.0608 - val_loss: 3.5823 - val_accuracy: 0.0810
# Epoch 3/30
# 60/60 [==============================] - 12s 196ms/step - loss: 3.4872 - accuracy: 0.0990 - val_loss: 3.3600 - val_accuracy: 0.1217
# Epoch 4/30
# 60/60 [==============================] - 12s 197ms/step - loss: 3.2299 - accuracy: 0.1420 - val_loss: 3.0214 - val_accuracy: 0.2249
# Epoch 5/30
# 60/60 [==============================] - 12s 196ms/step - loss: 2.7426 - accuracy: 0.2589 - val_loss: 2.3394 - val_accuracy: 0.3623
# Epoch 6/30
# 60/60 [==============================] - 12s 192ms/step - loss: 2.0453 - accuracy: 0.3964 - val_loss: 1.6015 - val_accuracy: 0.5079
# Epoch 7/30
# 60/60 [==============================] - 11s 192ms/step - loss: 1.5497 - accuracy: 0.5157 - val_loss: 1.3205 - val_accuracy: 0.5938
# Epoch 8/30
# 60/60 [==============================] - 11s 191ms/step - loss: 1.2741 - accuracy: 0.5973 - val_loss: 0.9596 - val_accuracy: 0.7343
# Epoch 9/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.9836 - accuracy: 0.6978 - val_loss: 0.6672 - val_accuracy: 0.8148
# Epoch 10/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.7484 - accuracy: 0.7705 - val_loss: 0.4817 - val_accuracy: 0.8752
# Epoch 11/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.6112 - accuracy: 0.8157 - val_loss: 0.3893 - val_accuracy: 0.8958
# Epoch 12/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.5111 - accuracy: 0.8471 - val_loss: 0.3069 - val_accuracy: 0.9208
# Epoch 13/30
# 60/60 [==============================] - 11s 192ms/step - loss: 0.4305 - accuracy: 0.8741 - val_loss: 0.2695 - val_accuracy: 0.9343
# Epoch 14/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.3761 - accuracy: 0.8874 - val_loss: 0.2082 - val_accuracy: 0.9478
# Epoch 15/30
# 60/60 [==============================] - 12s 198ms/step - loss: 0.3402 - accuracy: 0.8974 - val_loss: 0.1883 - val_accuracy: 0.9529
# Epoch 16/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.3051 - accuracy: 0.9063 - val_loss: 0.1708 - val_accuracy: 0.9559
# Epoch 17/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.2802 - accuracy: 0.9152 - val_loss: 0.1598 - val_accuracy: 0.9593
# Epoch 18/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.2539 - accuracy: 0.9246 - val_loss: 0.1531 - val_accuracy: 0.9635
# Epoch 19/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.2374 - accuracy: 0.9307 - val_loss: 0.1346 - val_accuracy: 0.9667
# Epoch 20/30
# 60/60 [==============================] - 11s 192ms/step - loss: 0.2136 - accuracy: 0.9373 - val_loss: 0.1153 - val_accuracy: 0.9705
# Epoch 21/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.1923 - accuracy: 0.9436 - val_loss: 0.1196 - val_accuracy: 0.9684
# Epoch 22/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.1822 - accuracy: 0.9446 - val_loss: 0.1151 - val_accuracy: 0.9709
# Epoch 23/30
# 60/60 [==============================] - 12s 193ms/step - loss: 0.1727 - accuracy: 0.9486 - val_loss: 0.1129 - val_accuracy: 0.9709
# Epoch 24/30
# 60/60 [==============================] - 11s 190ms/step - loss: 0.1583 - accuracy: 0.9531 - val_loss: 0.0982 - val_accuracy: 0.9753
# Epoch 25/30
# 60/60 [==============================] - 11s 192ms/step - loss: 0.1566 - accuracy: 0.9549 - val_loss: 0.0974 - val_accuracy: 0.9740
# Epoch 26/30
# 60/60 [==============================] - 11s 192ms/step - loss: 0.1441 - accuracy: 0.9569 - val_loss: 0.0942 - val_accuracy: 0.9769
# Epoch 27/30
# 60/60 [==============================] - 11s 191ms/step - loss: 0.1438 - accuracy: 0.9568 - val_loss: 0.0832 - val_accuracy: 0.9788
# Epoch 28/30
# 60/60 [==============================] - 12s 193ms/step - loss: 0.1374 - accuracy: 0.9592 - val_loss: 0.0807 - val_accuracy: 0.9807
# Epoch 29/30
# 60/60 [==============================] - 11s 189ms/step - loss: 0.1230 - accuracy: 0.9628 - val_loss: 0.0830 - val_accuracy: 0.9799
# Epoch 30/30
# 60/60 [==============================] - 12s 194ms/step - loss: 0.1173 - accuracy: 0.9649 - val_loss: 0.0787 - val_accuracy: 0.9802

# %% [markdown]
# ## Test Accuracy

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print('test set accuracy: ', accuracy * 100)
# Out:
# 491/491 [==============================] - 2s 4ms/step - loss: 0.0787 - accuracy: 0.9802
# test set accuracy:  98.01708459854126

# %% [markdown]
# ## Plotting accuracy and loss curves

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predictions on test images

# %%
from sklearn.metrics import accuracy_score
import pandas as pd

Y_test = pd.read_csv(data_dir + 'Test.csv')
test_labels = Y_test["ClassId"].values
test_images = Y_test["Path"].values

output = list()
for img in test_images:
    image = load_img(os.path.join(data_dir, img), target_size=(30, 30))
    output.append(np.array(image))

X_test=np.array(output)
pred = model.predict(X_test)
pred_new = np.argmax(pred,axis=1)

#Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(test_labels, pred_new)*100)
# Out:
# Test Data accuracy:  93.52335708630245

# %% [markdown]
# ## Visualizing the predictions

# %%
plt.figure(figsize = (13, 13))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = pred_new[start_index + i]
    actual = test_labels[start_index + i]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}'.format(actual, prediction), color = col)
    plt.imshow(X_test[start_index + i])
plt.show()

# %% [markdown]
# ## Saving the model

# %%
model.save('../model/heavy_model.h5')
